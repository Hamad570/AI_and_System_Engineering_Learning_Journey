# %% [markdown]
# # Scikit-Learn (Machine Learning)

# %%
"""
Classification
Train Logistic Regression model.
Predict diabetes using logistic regression.
Train KNN classifier.
Train Decision Tree classifier.
Train Random Forest classifier.
Train Naive Bayes classifier.
Train Support Vector Machine model.
Compare multiple classification models.
Predict student pass/fail.
Predict spam emails.
Clustering
Apply KMeans clustering.
Find optimal K value using elbow method.
Visualize clusters.
Group customers using clustering.
Apply DBSCAN clustering.
Model Evaluation
Create confusion matrix.
Calculate accuracy score.
Calculate precision score.
Calculate recall score.
Calculate F1-score.
Generate classification report.
Plot ROC curve.
Calculate Mean Squared Error.
Perform cross validation.
Detect overfitting and underfitting.
Advanced Beginner ML
Create pipeline using sklearn Pipeline.
Perform GridSearchCV for hyperparameter tuning.
Save trained model using joblib.
Load saved model and predict.
Perform feature scaling before ML.
Build end-to-end ML workflow.
Train model on CSV dataset.
Predict using user input values.
Compare training and testing accuracy.
Build mini ML project from dataset.
EDA (Exploratory Data Analysis) — 50 Programs
Dataset Basics
Load dataset using pandas.
Display first 5 rows of dataset.
Display last 5 rows of dataset.
Check dataset shape.
Check dataset columns.
Check datatypes of columns.
Generate summary statistics.
Find missing values.
Count total missing values.
Check duplicate rows.
Cleaning Data
Remove duplicate rows.
Fill missing values with mean.
Fill missing values with median.
Fill missing values with mode.
Drop rows with missing values.
Rename dataset columns.
Convert datatype of columns.
Remove unwanted columns.
Detect outliers using IQR method.
Remove outliers from dataset.
Data Analysis
Find average salary from dataset.
Find highest and lowest values.
Count unique values in column.
Find correlation between columns.
Group data using groupby().
Analyze department-wise salaries.
Analyze gender distribution.
Find top 10 highest values.
Find most frequent category.
Sort dataset based on column."""
# Out:
# '\nClassification\nTrain Logistic Regression model.\nPredict diabetes using logistic regression.\nTrain KNN classifier.\nTrain Decision Tree classifier.\nTrain Random Forest classifier.\nTrain Naive Bayes classifier.\nTrain Support Vector Machine model.\nCompare multiple classification models.\nPredict student pass/fail.\nPredict spam emails.\nClustering\nApply KMeans clustering.\nFind optimal K value using elbow method.\nVisualize clusters.\nGroup customers using clustering.\nApply DBSCAN clustering.\nModel Evaluation\nCreate confusion matrix.\nCalculate accuracy score.\nCalculate precision score.\nCalculate recall score.\nCalculate F1-score.\nGenerate classification report.\nPlot ROC curve.\nCalculate Mean Squared Error.\nPerform cross validation.\nDetect overfitting and underfitting.\nAdvanced Beginner ML\nCreate pipeline using sklearn Pipeline.\nPerform GridSearchCV for hyperparameter tuning.\nSave trained model using joblib.\nLoad saved model and predict.\nPerform feature scalin
# ...

# %%
import sklearn
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Preprocessing

# %%
#Load dataset using sklearn.
data=sklearn.('dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\city\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\__init__.py:133, in __getattr__(name)
#     132 try:
# --> 133     return globals()[name]
#     134 except KeyError:
#
# KeyError: 'load'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Load dataset using sklearn.
# ----> 2 data=sklearn.load('dataset.csv')
#
# File c:\Users\city\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\__init__.py:135, in __getattr__(name)
#     133     return globals()[name]
#     134 except KeyError:
# --> 135     raise AttributeError(f"Module 'sklearn' has no attribute '{name}'")
#
# AttributeError: Module 'sklearn' has no attribute 'load'

# %%
#Split dataset into train and test sets.
Normalize dataset using MinMaxScaler.
Standardize dataset using StandardScaler.
Encode categorical data using LabelEncoder.
Apply OneHotEncoder on dataset.
Handle missing values using SimpleImputer.
Select important features.
Reduce dimensions using PCA.
Shuffle dataset rows.
Linear Regression
Train simple linear regression model.
Predict house prices using linear regression.
Plot regression line.
Calculate regression accuracy score.
Train multiple linear regression model.
# Out:
#   Cell In[3], line 2
#     Normalize dataset using MinMaxScaler.
#               ^
# SyntaxError: invalid syntax
