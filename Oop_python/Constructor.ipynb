# %% [markdown]
# # Constructors & Object Methods
# Create default constructor example.
# Create parameterized constructor example.
# Create class with multiple methods.
# Create object counter using class variable.
# Create class variable shared by all objects.
# Create instance variable example.
# Print object details using method.
# Create method to compare two objects.
# Create destructor example.
# Create menu-driven class system.
